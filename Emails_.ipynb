# %%
import sqlite3 as sql
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

db_path = "C:/sql/databases/database.sqlite"
con = sql.connect(db_path)

cur = con.cursor()


query = """
SELECT *
FROM sqlite_master
WHERE type='table';
"""

results = cur.execute(query).fetchall()
print(results)
# Out:
# [('table', 'Emails', 'Emails', 2, 'CREATE TABLE Emails (\n    Id INTEGER PRIMARY KEY,\n    DocNumber TEXT,\n    MetadataSubject TEXT,\n    MetadataTo TEXT,\n    MetadataFrom TEXT,\n    SenderPersonId INTEGER,\n    MetadataDateSent TEXT,\n    MetadataDateReleased TEXT,\n    MetadataPdfLink TEXT,\n    MetadataCaseNumber TEXT,\n    MetadataDocumentClass TEXT,\n    ExtractedSubject TEXT,\n    ExtractedTo TEXT,\n    ExtractedFrom TEXT,\n    ExtractedCc TEXT,\n    ExtractedDateSent TEXT,\n    ExtractedCaseNumber TEXT,\n    ExtractedDocNumber TEXT,\n    ExtractedDateReleased TEXT,\n    ExtractedReleaseInPartOrFull TEXT,\n    ExtractedBodyText TEXT,\n    RawText TEXT)'), ('table', 'Persons', 'Persons', 3, 'CREATE TABLE Persons (\n    Id INTEGER PRIMARY KEY,\n    Name TEXT)'), ('table', 'Aliases', 'Aliases', 4, 'CREATE TABLE Aliases (\n    Id INTEGER PRIMARY KEY,\n    Alias TEXT,\n    PersonId INTEGER)'), ('table', 'EmailReceivers', 'EmailReceivers', 5, 'CREATE TABLE EmailReceivers (\n    Id INTEGER PRIMARY KEY,\n    EmailId INTEGER,\n    PersonId INTEGER)')]

# %%
emails = pd.read_sql("""SELECT * FROM Emails;""",con)


query2 = """
SELECT MetadataSubject
FROM Emails;"""
pd.read_sql_query(query2, con)
# Out:
#                                         MetadataSubject
# 0                                                   WOW
# 1     H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2                                         CHRIS STEVENS
# 3                            CAIRO CONDEMNATION - FINAL
# 4     H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# ...                                                 ...
# 7940                                              WYDEN
# 7941                                             SENATE
# 7942                                      RICHARD (TNR)
# 7943                                              FROM
# 7944                         NOTE FOR SECRETARY CLINTON
#
# [7945 rows x 1 columns]

# %%
query3 = """
SELECT MetadataTo,
    COUNT(*) AS most_frequent
FROM Emails
GROUP BY MetaDataTo
ORDER BY most_frequent DESC
;"""

pd.read_sql_query(query3, con)
# Out:
#                    MetadataTo  most_frequent
# 0                           H           5370
# 1           abedinh@state.gov            337
# 2           millscd@state.gov            311
# 3        sullivanjj@state.gov            297
# 4                                        255
# ..                        ...            ...
# 231  Beale, Courtney A Kramer              1
# 232                  BStrider              1
# 233                 Axelrod_D              1
# 234                  ASUNCION              1
# 235                        ;H              1
#
# [236 rows x 2 columns]

# %%
query4 = """
SELECT MetadataFrom,
    COUNT(*) AS most_received
    FROM Emails
    GROUP BY MetadataFrom
    ORDER BY most_received DESC;"""


pd.read_sql_query(query4, con)
# Out:
#                      MetadataFrom  most_received
# 0                               H           1906
# 1                    Abedin, Huma           1380
# 2                 Mills, Cheryl D           1146
# 3               Sullivan, Jacob J            750
# 4                        sbwhoeop            316
# ..                            ...            ...
# 285                   Abein, Huma              1
# 286                            AP              1
# 287  AGNA USEMB Kabul Afghanistan              1
# 288       AF/PDPA:Scott, Marianne              1
# 289                111th Congress              1
#
# [290 rows x 2 columns]

# %%
query5 ="""
SELECT MetadataTo,MetadataDateSent,
    COUNT(MetadataTo) AS number_of_emails_sent
FROM Emails
GROUP BY MetadataDateSent
ORDER BY number_of_emails_sent DESC;
"""
pd.read_sql_query(query5,con)
# Out:
#                  MetadataTo           MetadataDateSent  number_of_emails_sent
# 0                    Cheryl                                               132
# 1              cheryl.mills  2009-09-20T04:00:00+00:00                     48
# 2    balderstonkm@state.gov  2009-12-23T05:00:00+00:00                     47
# 3                         H  2010-03-21T04:00:00+00:00                     46
# 4                         H  2010-02-10T05:00:00+00:00                     45
# ..                      ...                        ...                    ...
# 759                          2009-01-15T05:00:00+00:00                      1
# 760                          2009-01-12T05:00:00+00:00                      1
# 761                          2009-01-06T05:00:00+00:00                      1
# 762                          2009-01-04T05:00:00+00:00                      1
# 763                          2008-05-01T04:00:00+00:00                      1
#
# [764 rows x 3 columns]

# %%
query6 ="""
SELECT MetadataFrom,MetadataDateSent,
    COUNT(MetadataFrom) AS number_of_emails_received
FROM Emails
GROUP BY MetadataDateSent
ORDER BY number_of_emails_received DESC;
"""
pd.read_sql_query(query6,con)
# Out:
#             MetadataFrom           MetadataDateSent  number_of_emails_received
# 0                   Alec                                                   132
# 1                      H  2009-09-20T04:00:00+00:00                         48
# 2                      H  2009-12-23T05:00:00+00:00                         47
# 3               sbwhoeop  2010-03-21T04:00:00+00:00                         46
# 4      Sullivan, Jacob J  2010-02-10T05:00:00+00:00                         45
# ..                   ...                        ...                        ...
# 759                State  2009-01-15T05:00:00+00:00                          1
# 760                       2009-01-12T05:00:00+00:00                          1
# 761                       2009-01-06T05:00:00+00:00                          1
# 762              S/SRGIA  2009-01-04T05:00:00+00:00                          1
# 763  FINCA International  2008-05-01T04:00:00+00:00                          1
#
# [764 rows x 3 columns]

# %%
query7 = """
SELECT Name
FROM Persons
ORDER BY Name;"""
pd.read_sql_query(query7, con)
# Out:
#                                    Name
# 0                                     .
# 1                         . huma abedin
# 2                   . vermarr@state.gov
# 3                 ..lilotylc@state.gov.
# 4                   .1ilotylc@state.gov
# ..                                  ...
# 508                      williamsbarre0
# 509                      williamsbarret
# 510  williamsbarrett millscd@state.gov.
# 511                 woodardew@state.gov
# 512                 yeryeerms@state.goy
#
# [513 rows x 1 columns]

# %%
df = pd.read_sql("""SELECT * FROM Emails;""",con)
cur.close()
con.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7945 entries, 0 to 7944
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Id                            7945 non-null   int64
#  1   DocNumber                     7945 non-null   object
#  2   MetadataSubject               7945 non-null   object
#  3   MetadataTo                    7945 non-null   object
#  4   MetadataFrom                  7945 non-null   object
#  5   SenderPersonId                7945 non-null   object
#  6   MetadataDateSent              7945 non-null   object
#  7   MetadataDateReleased          7945 non-null   object
#  8   MetadataPdfLink               7945 non-null   object
#  9   MetadataCaseNumber            7945 non-null   object
#  10  MetadataDocumentClass         7945 non-null   object
#  11  ExtractedSubject              7945 non-null   object
#  12  ExtractedTo                   7945 non-null   object
#  13  ExtractedFrom                 7945 non-null   object
#  14  ExtractedCc                   7945 non-null   object
#  15  ExtractedDateSent             7945 non-null   object
#  16  ExtractedCaseNumber           7945 non-null   object
#  17  ExtractedDocNumber            7945 non-null   object
#  18  ExtractedDateReleased         7945 non-null   object
#  19  ExtractedReleaseInPartOrFull  7945 non-null   object
#  20  ExtractedBodyText             7945 non-null   object
#  21  RawText                       7945 non-null   object
# dtypes: int64(1), object(21)
# memory usage: 1.3+ MB

# %%
df.isna().sum()
df.duplicated().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 5   6  C05739559  MEET THE RIGHT-WING EXTREMIST BEHIND ANTI-MUSL...
# 6   7  C05739560  ANTI-MUSLIM FILM DIRECTOR IN HIDING, FOLLOWING...
# 7   8  C05739561  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 8   9  C05739562                                SECRETARY'S REMARKS
# 9  10  C05739563                                      MORE ON LIBYA
#
#           MetadataTo       MetadataFrom SenderPersonId  \
# 0                  H  Sullivan, Jacob J             87
# 1                  H
# 2                 ;H    Mills, Cheryl D             32
# 3                  H    Mills, Cheryl D             32
# 4       Abedin, Huma                  H             80
# 5  Russorv@state.gov                  H             80
# 6                  H    Mills, Cheryl D             32
# 7       Abedin, Huma                  H             80
# 8                  H  Sullivan, Jacob J             87
# 9                  H
#
#             MetadataDateSent       MetadataDateReleased  \
# 0  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 1  2011-03-03T05:00:00+00:00  2015-05-22T04:00:00+00:00
# 2  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 3  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 4  2011-03-11T05:00:00+00:00  2015-05-22T04:00:00+00:00
# 5  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 6  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 7  2011-03-11T05:00:00+00:00  2015-05-22T04:00:00+00:00
# 8  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 9  2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
#
#                                      MetadataPdfLink MetadataCaseNumber  ...  \
# 0  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841  ...
# 1  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841  ...
# 2  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841  ...
# 3  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739550...       F-2015-04841  ...
# 4  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739554...       F-2015-04841  ...
# 5  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739559...       F-2015-04841  ...
# 6  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739560...       F-2015-04841  ...
# 7  DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739561...       F-2015-04841  ...
# 8  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739562...       F-2015-04841  ...
# 9  DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739563...       F-2015-04841  ...
#
#   ExtractedTo                             ExtractedFrom         ExtractedCc  \
# 0              Sullivan, Jacob J <Sullivan11@state.gov>
# 1
# 2          B6       Mills, Cheryl D <MillsCD@state.gov>        Abedin, Huma
# 3                   Mills, Cheryl D <MillsCD@state.gov>  Mitchell, Andrew B
# 4
# 5
# 6                   Mills, Cheryl D <MillsCD@state.gov>
# 7
# 8               Sullivan, Jacob J <Sullivanli@stategov>
# 9
#
#                         ExtractedDateSent ExtractedCaseNumber  \
# 0  Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 1                                                F-2015-04841
# 2  Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 3   Wednesday, September 12,2012 12:44 PM        F-2015-04841
# 4                                                F-2015-04841
# 5  Wednesday, September 12, 2012 01:00 PM        F-2015-04841
# 6   Wednesday, September 12, 2012 4:00 PM        F-2015-04841
# 7                                                F-2015-04841
# 8   Wednesday, September 12, 2012 6:08 PM        F-2015-04841
# 9                                                F-2015-04841
#
#   ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# 0          C05739545            05/13/2015              RELEASE IN FULL
# 1          C05739546            05/13/2015              RELEASE IN PART
# 2          C05739547            05/14/2015              RELEASE IN PART
# 3          C05739550            05/13/2015              RELEASE IN PART
# 4          C05739554            05/13/2015              RELEASE IN PART
# 5          C05739559            05/13/2015              RELEASE IN PART
# 6          C05739560            05/13/2015              RELEASE IN FULL
# 7          C05739561            05/13/2015              RELEASE IN PART
# 8          C05739562            05/13/2015              RELEASE IN FULL
# 9          C05739563            05/13/2015              RELEASE IN PART
#
#                                    ExtractedBodyText  \
# 0
# 1  B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 2                                                Thx
# 3
# 4  H <hrod17@clintonemail.com>\nFriday, March 11,...
# 5  Pis print.\n-•-...-^\nH < hrod17@clintonernail...
# 6
# 7  H <hrod17@clintonemail.corn>\nFriday, March 11...
# 8                                                FYI
# 9  B6\nWednesday, September 12, 2012 6:16 PM\nFwd...
#
#                                              RawText
# 0  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 1  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
# 5  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
# 6  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 7  B6\nUNCLASSIFIED\nU.S. Department of State\nCa...
# 8  UNCLASSIFIED\nU.S. Department of State\nCase N...
# 9  UNCLASSIFIED\nU.S. Department of State\nCase N...
#
# [10 rows x 22 columns]

# %%
import re
import nltk
from nltk.stem import WordNetLemmatizer,PorterStemmer,SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("stowords")
import string

def clean_text(text):
    
    text = str(text).lower()
    
    text = re.sub(r'<.*?>', '',text)
    
    text = re.sub('https?://\S+|www\.\S+', '', text)


    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    
    text = re.sub(r'\@w+|\#','',text)
    

    
    
    return text


df['MetadataSubject'] = df['MetadataSubject'].apply(clean_text)
df['MetadataTo'] = df['MetadataTo'].apply(clean_text)
df['MetadataFrom'] = df['MetadataFrom'].apply(clean_text)
df['ExtractedCc'] = df['ExtractedCc'].apply(clean_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\katsa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\katsa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading stowords: Package 'stowords' not found in
# [nltk_data]     index

# %%
sw = set(stopwords.words("english"))

def remove_stopwords(text):
    tokens = word_tokenize(text)
    cleaned_tokens = [word for word in tokens if word.lower() not in sw]
    return " ".join(cleaned_tokens)

df['MetadataSubject'] = df['MetadataSubject'].apply(remove_stopwords)
df['MetadataSubject'].head(10)
df['MetadataTo'] = df['MetadataTo'].apply(remove_stopwords)
df['MetadataFrom'] = df['MetadataFrom'].apply(remove_stopwords)
df['ExtractedCc'] = df['ExtractedCc'].apply(remove_stopwords)
df['ExtractedCc'].head(10)
# Out:
# 0
# 1
# 2          abedin huma
# 3    mitchell andrew b
# 4
# 5
# 6
# 7
# 8
# 9
# Name: ExtractedCc, dtype: object

# %%
w = WordNetLemmatizer()

def lem_text(text):
    tokens = word_tokenize(text)
    stem_tokens = [w.lemmatize(token) for token in tokens]
    return " ".join(stem_tokens)

df['MetadataSubject'] = df['MetadataSubject'].apply(lem_text)
df['MetadataSubject'].head(10)
df['MetadataTo'] = df['MetadataTo'].apply(lem_text)
df['MetadataFrom'] = df['MetadataFrom'].apply(lem_text)
df['ExtractedCc'] = df['ExtractedCc'].apply(lem_text)
df['MetadataFrom'].head(10)
# Out:
# 0    sullivan jacob j
# 1
# 2         mill cheryl
# 3         mill cheryl
# 4                   h
# 5                   h
# 6         mill cheryl
# 7                   h
# 8    sullivan jacob j
# 9
# Name: MetadataFrom, dtype: object

# %%
meta_subject = " ".join(i for i in df['MetadataSubject'])
meta_to = " ".join(i for i in df['MetadataTo'])
meta_from = " ".join(i for i in df['MetadataFrom'])
cc_text = " ".join(i for i in df['ExtractedCc'])

from wordcloud import WordCloud
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

wc = WordCloud(colormap="Set3",collocations=False).generate(meta_subject)
plt.imshow(wc,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wc = WordCloud(colormap="Set3",collocations=False).generate(meta_to)
plt.imshow(wc,interpolation="blackman")
plt.axis("off")
plt.show()

# %%
wc = WordCloud(colormap="Set2",collocations=False).generate(meta_from)
plt.imshow(wc,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wc = WordCloud(colormap="Set2",collocations=False).generate(cc_text)
plt.imshow(wc,interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
print(meta_subject)
# Out:
# wow h latest syria aiding qaddafi sid chris stevens cairo condemnation final h latest syria aiding qaddafi sid meet rightwing extremist behind antimuslim film sparked deadly riot antimuslim film director hiding following libya egypt violence h latest syria aiding qaddafi sid secretary remark libya abz hbj libya west bankgaza libya hey piece libya nfz appear nyt oped page tomorrow dry eye nea thank youth libya one photo today youth libya libya libya h magariaf attack u libya sid h magariaf attack u libya sid proposed quad deal h magariaf privat reax sent memo sid libya amb stevens cnn belief blog prothero chris stevens mission quick summary potus call president libya egypt wash post hillary clinton try calm antius sentiment protester storm embassy yemen h lot new intel possible libyan collapse sid quick summary potus call president libya egypt condolence pm netanyahu american killed libya intel mission track weapon mini today friday september 14 2012 situation report 1 0914i situation report 1 0914i great work thanks making hero homecoming deserved libyan great work thanks making hero homecoming deserved benhaziprotest statement libyan pretty powerful piece standing diplomat libyan h romneys last gambit got done published sid libyan h romneys last gambit got done published sid great work thanks making hero homecoming deserved h romneys last gambit got done published sid gorgeous pic front page nyt h romneys last gambit got done published sid h morsis private conversation today sid thanks h romneys last gambit got done published sid thanks h romneys last gambit got done published sid statement press secretary fw gorgeous pic front page nyt benghazi obamas 3 call remark tripoli trip daily beast diplomat fire brit libya brit libya cnn belief blog prothero mission benghazi h great see drop here libya sid h great see drop here libya sid pdb exclusive bill clinton say wouldnt rule arming libya rebel h great see drop here libya sid item benghazi nato h great see drop here libya sid h great see drop here libya sid saudi grand mufti call attack foreign embassy unislamic reuters cable romney compare benghazi original 911 attack h uk game playing new rebel strategist egypt move sid condolence cable romney compare benghazi original 911 attack u intelligence warned embassy egypt concern antimuslim film hill issa target hillary big mistake h uk game playing new rebel strategist egypt move sid speech draft friday csis question update speech draft friday csis question update speech draft friday csis stevens update important pdb speech draft friday csis update situation benghazi mccain visit benghazi staffing pdb monica langley transcript holder mccain update ending speech mccain update ending speech holder stevens update ending speech hrc csis v8 stevens update benghazi 426 7am ending speech holder special envoy stevens report benghazi 426 1200 holder holder h ubl aq libya sid king morocco king morocco secretary state hillary rodham clinton remark maghreb transition center strategic international study washington dc october 12 2012 king morocco h ubl aq libya sid q hbj king morocco h ubl aq libya sid csis king morocco h ubl aq libya sid bloomberg libyan ambassador death political issue say dad rice week h new memo q secret bid uk sid visa obtained visa obtained h memo attached q secret bid uk sid bloomberg libyan ambassador death political issue say dad bloomberg libyan ambassador death political issue say dad h memo attached q secret bid uk sid meet press transcript u ambassador united nation susan rice state union transcript u ambassador united nation susan rice bloomberg libyan ambassador death political issue say dad tripoli personnel h new memo q secret bid uk sid meet press transcript u ambassador united nation susan rice hotel benghazi h killed younis sid meet press transcript u ambassador united nation susan rice salon death ambassador chris stevens need expeditionary diplomacy real lesson u diplomacy meant email earlier thanks jeff up ...

# %%
subject_blob = TextBlob(meta_subject)
meta_blob = TextBlob(meta_to)
meta_from = TextBlob(meta_from)


from nltk.probability import FreqDist

most_common_words_in_subject = FreqDist(subject_blob.words)
top_50_most_common_words_in_subject = most_common_words_in_subject.most_common(50)
print("top 50 most common words in subject: ",top_50_most_common_words_in_subject)
# Out:
# top 50 most common words in subject:  [('call', 645), ('sid', 339), ('schedule', 259), ('h', 257), ('speech', 217), ('u', 216), ('update', 210), ('talk', 201), ('haiti', 161), ('ap', 159), ('fyi', 149), ('reuters', 147), ('secretary', 134), ('today', 132), ('new', 126), ('statement', 126), ('tomorrow', 117), ('report', 117), ('meeting', 108), ('mini', 101), ('foreign', 99), ('draft', 98), ('memo', 94), ('clinton', 91), ('fw', 85), ('list', 82), ('office', 78), ('iran', 78), ('holbrooke', 75), ('question', 71), ('latest', 70), ('letter', 69), ('pm', 68), ('say', 66), ('pakistan', 66), ('state', 65), ('note', 62), ('minister', 62), ('libya', 61), ('news', 61), ('right', 61), ('confirmed', 58), ('back', 57), ('good', 55), ('thank', 54), ('friday', 54), ('email', 54), ('monday', 54), ('election', 53), ('honduras', 53)]

# %%
most_common_words_in_sent_emails = FreqDist(meta_blob.words)
top_50_most_common_words_sent = most_common_words_in_sent_emails.most_common(50)
print(top_50_most_common_words_sent)
# Out:
# [('h', 5381), ('abedinhstategov', 352), ('millscdstategov', 312), ('sullivanjjstategov', 298), ('jilotylcstategov', 234), ('valmoroljstategov', 144), ('abedin', 80), ('huma', 80), ('preines', 60), ('sbwhoeop', 49), ('hillary', 49), ('cherylmills', 45), ('j', 39), ('cheryl', 38), ('mill', 37), ('hanleymrstategov', 34), ('h2', 33), ('jacob', 31), ('vermarrstategov', 30), ('slaughterastategov', 29), ('sullivan', 28), ('russorvstategov', 26), ('oscar', 19), ('flores', 18), ('muscatinelstategov', 18), ('jakesullivan', 17), ('balderstonkmstategov', 16), ('reinespstategov', 13), ('stalbott', 10), ('verveermsstategov', 10), ('pverveer', 10), ('crowleypjstategov', 10), ('secretary', 10), ('clinton', 10), ('mchalejastategov', 10), ('campbellkmstategov', 9), ('slaughter', 9), ('r', 8), ('steinbergjbstategov', 8), ('doug', 8), ('annemarie', 8), ('lewjjstategov', 7), ('capriciamarshall', 7), ('c', 7), ('lew', 7), ('tillemanntsstategov', 7), ('shapiroastategov', 6), ('rooneymstategov', 6), ('verma', 6), ('richard', 6)]

# %%
most_common_words_in_emails_received = FreqDist(meta_from.words)
top_50_most_common_words_in_emails_received = most_common_words_in_sent_emails.most_common(50)
print("top 50 words in emails received",top_50_most_common_words_in_emails_received)
# Out:
# top 50 words in emails received [('h', 5381), ('abedinhstategov', 352), ('millscdstategov', 312), ('sullivanjjstategov', 298), ('jilotylcstategov', 234), ('valmoroljstategov', 144), ('abedin', 80), ('huma', 80), ('preines', 60), ('sbwhoeop', 49), ('hillary', 49), ('cherylmills', 45), ('j', 39), ('cheryl', 38), ('mill', 37), ('hanleymrstategov', 34), ('h2', 33), ('jacob', 31), ('vermarrstategov', 30), ('slaughterastategov', 29), ('sullivan', 28), ('russorvstategov', 26), ('oscar', 19), ('flores', 18), ('muscatinelstategov', 18), ('jakesullivan', 17), ('balderstonkmstategov', 16), ('reinespstategov', 13), ('stalbott', 10), ('verveermsstategov', 10), ('pverveer', 10), ('crowleypjstategov', 10), ('secretary', 10), ('clinton', 10), ('mchalejastategov', 10), ('campbellkmstategov', 9), ('slaughter', 9), ('r', 8), ('steinbergjbstategov', 8), ('doug', 8), ('annemarie', 8), ('lewjjstategov', 7), ('capriciamarshall', 7), ('c', 7), ('lew', 7), ('tillemanntsstategov', 7), ('shapiroastategov', 6), ('rooneymstategov', 6), ('verma', 6), ('richard', 6)]

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['MetadataDateReleased'],y=df['MetadataFrom'])
plt.title("time frame of emails received")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df['MetadataDateReleased'],y=df['MetadataTo'])
plt.title("time frame of emails Sent")
plt.show()

# %%
df['ExtractedReleaseInPartOrFull'] = [1 if X == "RELEASE IN PART" else 0 for X in df['ExtractedReleaseInPartOrFull']]
plt.figure(figsize=(12,6))
plt.title("emails released in-part or in-full")
sns.countplot(x='MetadataDateReleased',data=df)
plt.show()

# %%
from tensorflow.keras.utils import pad_sequences,to_categorical

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding,SpatialDropout1D,Bidirectional,Dropout


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()


X = df['MetadataSubject']
y = df["ExtractedReleaseInPartOrFull"]

le.fit_transform(y)


X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.20,random_state=42)


from tensorflow.keras.utils import pad_sequences,to_categorical

from tensorflow.keras.preprocessing.text import Tokenizer
num_words = 30000

tokenizer = Tokenizer(num_words)

tokenizer.fit_on_texts(X_train)

word_index = tokenizer.word_index
print(len(word_index))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# 4309

# %%
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

max_length = 0
for sequence in X_train:
    sequence_length = len(sequence)
    if sequence_length > max_length:
        max_length = sequence_length


print(max_length)
X_train = pad_sequences(X_train,max_length,padding="post")
X_test = pad_sequences(X_test,max_length,padding="post")
# Out:
# 28

# %%
RNN = Sequential()
RNN.add(Embedding(len(word_index) + 1, output_dim=100, input_length=max_length))
RNN.add(SpatialDropout1D(0.3))
RNN.add(Bidirectional(LSTM(10,dropout=0.1,recurrent_dropout=0.1)))
RNN.add(Dropout(0.2))
RNN.add(Dense(50, activation='relu'))
RNN.add(Dropout(0.1))
RNN.add(Dense(2, activation='sigmoid'))

RNN.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = RNN.fit(X_train, y_train, batch_size=64, epochs=20, validation_split=0.1)
# Out:
# Epoch 1/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.5373 - loss: 0.6891 - val_accuracy: 0.5833 - val_loss: 0.6666
# Epoch 2/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6617 - loss: 0.6262 - val_accuracy: 0.7013 - val_loss: 0.5484
# Epoch 3/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7784 - loss: 0.4663 - val_accuracy: 0.7075 - val_loss: 0.5509
# Epoch 4/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8141 - loss: 0.3948 - val_accuracy: 0.7186 - val_loss: 0.5721
# Epoch 5/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.8345 - loss: 0.3503 - val_accuracy: 0.7186 - val_loss: 0.5895
# Epoch 6/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8397 - loss: 0.3315 - val_accuracy: 0.7280 - val_loss: 0.6001
# Epoch 7/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8451 - loss: 0.3046 - val_accuracy: 0.7217 - val_loss: 0.6159
# Epoch 8/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8506 - loss: 0.2933 - val_accuracy: 0.7264 - val_loss: 0.6287
# Epoch 9/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8541 - loss: 0.2831 - val_accuracy: 0.7296 - val_loss: 0.6597
# Epoch 10/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8627 - loss: 0.2695 - val_accuracy: 0.7264 - val_loss: 0.6725
# Epoch 11/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8528 - loss: 0.2849 - val_accuracy: 0.7453 - val_loss: 0.7152
# Epoch 12/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8632 - loss: 0.2535 - val_accuracy: 0.7421 - val_loss: 0.7129
# Epoch 13/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8527 - loss: 0.2633 - val_accuracy: 0.7358 - val_loss: 0.7230
# Epoch 14/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8741 - loss: 0.2455 - val_accuracy: 0.7484 - val_loss: 0.7516
# Epoch 15/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8669 - loss: 0.2580 - val_accuracy: 0.7469 - val_loss: 0.7782
# Epoch 16/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8699 - loss: 0.2534 - val_accuracy: 0.7421 - val_loss: 0.7961
# Epoch 17/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.8659 - loss: 0.2487 - val_accuracy: 0.7453 - val_loss: 0.8195
# Epoch 18/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8704 - loss: 0.2338 - val_accuracy: 0.7500 - val_loss: 0.8077
# Epoch 19/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8741 - loss: 0.2345 - val_accuracy: 0.7374 - val_loss: 0.8701
# Epoch 20/20
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8724 - loss: 0.2334 - val_accuracy: 0.7437 - val_loss: 0.8805
