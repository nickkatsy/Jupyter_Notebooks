# %%
# lol, pretend caring to explain the details...... IT works

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('C:/ML/python/data/animequotes.csv', delimiter=',')


df['Character'] = df['Character'].str.lower().str.replace('\W', ' ')
df['Quote'] = df['Quote'].str.lower().str.replace('\W', ' ')
df['Anime'] = df['Anime'].str.lower().str.replace('\W', ' ')

X = df['Quote']
y = df['Character']



from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=42)


tfidf = TfidfVectorizer()
X_tfidf_train = tfidf.fit_transform(X_train)
X_tfidf_test = tfidf.transform(X_test)

from sklearn.ensemble import GradientBoostingClassifier, BaggingClassifier,RandomForestClassifier
GBC = GradientBoostingClassifier()
BC = BaggingClassifier()
RFC = RandomForestClassifier()

from sklearn.svm import SVC
svc = SVC(probability=False)
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()

from sklearn.metrics import accuracy_score, classification_report


def evaluate_model(X_train,X_test,y_train,y_test,model):
    model = model.fit(X_train,y_train)
    pred = model.predict(X_tfidf_test)
    acc = accuracy_score(y_test,pred)
    clf_report = classification_report(y_test,pred)
    print(f'{model.__class__.__name__}, -- Classification Report -- {clf_report} Accuracy {acc*100:.2f}%')
    return pred


BC_pred = evaluate_model(X_tfidf_train, X_tfidf_test, y_train, y_test, BC)
GBC_pred = evaluate_model(X_tfidf_train, X_tfidf_test, y_train, y_test, GBC)
RFC_pred = evaluate_model(X_tfidf_train, X_tfidf_test, y_train, y_test, RFC)
svc_pred = evaluate_model(X_tfidf_train, X_tfidf_test, y_train, y_test, svc)
MNB_pred = evaluate_model(X_tfidf_train, X_tfidf_test, y_train, y_test, MNB)
# Out:
# BaggingClassifier, -- Classification Report --                       precision    recall  f1-score   support
#
#       alibaba saluja       0.50      1.00      0.67         1
#              alucard       0.00      0.00      0.00         1
#               archer       0.00      0.00      0.00         0
#         armin arlert       0.00      0.00      0.00         0
#               canaan       0.00      0.00      0.00         1
#         deneil young       0.00      0.00      0.00         1
#                 eren       0.00      0.00      0.00         0
#          erwin smith       0.00      0.00      0.00         0
# fuegoleon vermillion       0.00      0.00      0.00         0
#       gildarts clive       0.00      0.00      0.00         1
#                 goku       0.00      0.00      0.00         1
#       himura kenshin       0.00      0.00      0.00         0
#        itachi uchiha       0.00      0.00      0.00         1
#       ittetsu takeda       0.00      0.00      0.00         1
#       izuku midoriya       0.00      0.00      0.00         0
#            jet black       0.00      0.00      0.00         1
#              jiraiya       0.00      0.00      0.00         1
#        juuzou suzuya       0.00      0.00      0.00         1
#      kanade jinguuji       0.00      0.00      0.00         0
#      keiichi maebara       0.00      0.00      0.00         1
#       kenny ackerman       0.00      0.00      0.00         1
#       kenshin himura       0.00      0.00      0.00         1
#          kunio yaobi       0.00      0.00      0.00         1
#     kyousuke natsume       0.00      0.00      0.00         1
#        levi ackerman       0.00      0.00      0.00         1
#          maka albarn       0.00      0.00      0.00         1
#    matsumoto rangiku       0.00      0.00      0.00         1
#      miche zacharius       0.00      0.00      0.00         1
#            nobito       0.00      0.00      0.00         1
#   renton thurston       0.00      0.00      0.00         1
#              sora       0.00      0.00      0.00         1
#    tobio kageyama       0.00      0.00      0.00         0
#           tsunade       0.00      0.00      0.00         1
#
#          accuracy                           0.04        25
#         macro avg       0.04      0.04      0.04        25
#      weighted avg       0.04      0.04      0.04        25
#  Accuracy 4.00%
# MultinomialNB, -- Classification Report --                    precision    recall  f1-score   support
#
#    alibaba saluja       0.00      0.00      0.00       1.0
#           alucard       0.00      0.00      0.00       1.0
#      armin arlert       0.00      0.00      0.00       0.0
#            canaan       0.00      0.00      0.00       1.0
#      deneil young       0.00      0.00      0.00       1.0
#    gildarts clive       0.00      0.00      0.00       1.0
#              goku       0.00      0.00      0.00       1.0
#    himura kenshin       0.00      0.00      0.00       0.0
#     itachi uchiha       0.00      0.00      0.00       1.0
#    ittetsu takeda       0.00      0.00      0.00       1.0
#         jet black       0.00      0.00      0.00       1.0
#           jiraiya       0.00      0.00      0.00       1.0
#     juuzou suzuya       0.00      0.00      0.00       1.0
#   keiichi maebara       0.00      0.00      0.00       1.0
#    kenny ackerman       0.00      0.00      0.00       1.0
#    kenshin himura       0.00      0.00      0.00       1.0
#       kunio yaobi       0.00      0.00      0.00       1.0
#  kyousuke natsume       0.00      0.00      0.00       1.0
#     levi ackerman       0.00      0.00      0.00       1.0
#       maka albarn       0.00      0.00      0.00       1.0
# matsumoto rangiku       0.00      0.00      0.00       1.0
#   miche zacharius       0.00      0.00      0.00       1.0
#    monkey d luffy       0.00      0.00      0.00       0.0
#    naruto uzumaki       0.00      0.00      0.00       1.0
#            nobito       0.00      0.00      0.00       1.0
#   renton thurston       0.00      0.00      0.00       1.0
#              sora       0.00      0.00      0.00       1.0
#    tobio kageyama       0.00      0.00      0.00       0.0
#           tsunade       0.00      0.00      0.00       1.0
#
#          accuracy                           0.00      25.0
#         macro avg       0.00      0.00      0.00      25.0
#      weighted avg       0.00      0.00      0.00      25.0
#  Accuracy 0.00%

# %%
#lines spoken by all the anime lads. WEEBED OUT OF MY FACE
def get_lines_by_character(character,df):
    lines_spoken = df[df['Character'] == character]['Quote']
    return lines_spoken

unique_characters = df['Character'].unique()
for character in unique_characters:
    print(f'{character}:')
    lines_spoken = get_lines_by_character(character, df)
    print(lines_spoken)
# Out:
# itachi uchiha:
# 0    people s lives don t end when they die  it end...
# Name: Quote, dtype: object
# monkey d luffy:
# 1     if you don t take risks  you can t create a fu...
# 5     forgetting is like a wound  the wound may heal...
# 14      being lonely is more painful then getting hurt
# 61    no matter how hard or impossible it is  never ...
# Name: Quote, dtype: object
# naruto uzumaki:
# 2      if you don t like your destiny  don t accept it
# 31    hard work is worthless for those that don t be...
# 43    if you don t like your destiny  don t accept i...
# Name: Quote, dtype: object
# mitsuyoshi anzai:
# 3    when you give up  that s when the game ends
# Name: Quote, dtype: object
# deneil young:
# 4    all we can do is live until the day we die  co...
# Name: Quote, dtype: object
# reiko mikami:
# 6    it s just pathetic to give up on something bef...
# Name: Quote, dtype: object
# nagato:
# 7    if you don t share someone s pain  you can nev...
# Name: Quote, dtype: object
# himura kenshin:
# 8     whatever you lose  you ll find it again  but w...
# 34    you can die anytime  but living takes true cou...
# 91    you ll only realize that you truly love someon...
# Name: Quote, dtype: object
# natsu dragneel:
# 9     we don t have to know what tomorrow holds  tha...
# 59    the moment you think of giving up  think of th...
# Name: Quote, dtype: object
# juuzou suzuya:
# 10    why should i apologize for being a monster  ha...
# Name: Quote, dtype: object
# tsunade:
# 11    people become stronger because they have memor...
# Name: Quote, dtype: object
# saitama:
# 12     i ll leave tomorrow s problems to tomorrow s me
# 27    if you really want to be strong  stop caring a...
# 74    who decides limits  and based on what  you sai...
# Name: Quote, dtype: object
# seiya kanie:
# 13    if you wanna make people dream  you ve gotta s...
# Name: Quote, dtype: object
# shintar midorima:
# 15    there s no shame in falling down  true shame i...
# Name: Quote, dtype: object
# seishuu handa:
# 16    simplicity is the easiest path to true beauty
# Name: Quote, dtype: object
# shiroe:
# 17    if you can t do something  then don t  focus o...
# 57    if you can t do something  then don t  focus o...
# Name: Quote, dtype: object
# alucard:
# 18    giving up kills people  when people reject giv...
# Name: Quote, dtype: object
# kenshin himura:
# 19    you can die anytime  but living takes true cou...
# 26    whatever you lose  you ll find it again  but w...
# Name: Quote, dtype: object
# milly thompson:
# 20    every journey begins with a single step  we ju...
# 35    every journey begins with a single step  we ju...
# Name: Quote, dtype: object
# yuuya mochizuki:
# 21    it doesn t do any good to pretend you can t se...
# Name: Quote, dtype: object
# fuegoleon vermillion:
# 22    being weak is nothing to be ashamed of  stayin...
# Name: Quote, dtype: object
# hinata miyake:
# 23    to act is not necessarily compassion  true com...
# 29    sometimes  people are just mean  don t fight m...
# 71    when you hit the point of no return  that s th...
# Name: Quote, dtype: object
# rock lee:
# 24    a dropout will beat a genius through hard work
# Name: Quote, dtype: object
# simon:
# 25    reject common sense to make the impossible pos...
# Name: Quote, dtype: object
# touko aozaki:
# 28    vision is not what your eyes see  but an image...
# Name: Quote, dtype: object
# vash the stampede:
# 30    the ticket to the future is always open
# Name: Quote, dtype: object
# jiraiya:
# 32    a place where someone still thinks about you i...
# 73    a person grows up when he s able to overcome h...
# Name: Quote, dtype: object
# yuuji kazami:
# 33    life comes at a cost  wouldn t it be arrogant ...
# Name: Quote, dtype: object
# keiichi maebara:
# 36    if you just submit yourself to fate  then that...
# Name: Quote, dtype: object
# archer:
# 37    it is at the moment of death that humanity has...
# 97    do not think about other things  there is only...
# Name: Quote, dtype: object
# armin arlert:
# 38     people  who can t throw something important aw...
# 102    if there are humans who can bring about change...
# 103    i don t like the terms good person or bad pers...
# Name: Quote, dtype: object
# rider:
# 39    whatever you do  enjoy it to the fullest  that...
# Name: Quote, dtype: object
# goku:
# 40    power comes in response to a need  not a desir...
# Name: Quote, dtype: object
# saber:
# 41    there are no regrets  if one can be proud of o...
# Name: Quote, dtype: object
# kunio yaobi:
# 42    you can t always hold on to the things that ar...
# Name: Quote, dtype: object
# renton thurston:
# 44    don t beg for things  do it yourself  or else ...
# Name: Quote, dtype: object
# maka albarn:
# 45    i refuse to let my fear control me anymore
# Name: Quote, dtype: object
# akame:
# 46    if you can t find a reason to fight  then you ...
# Name: Quote, dtype: object
# canaan:
# 47    you should never give up on life  no matter ho...
# Name: Quote, dtype: object
# armin arlelt:
# 48    people who can t throw something important awa...
# Name: Quote, dtype: object
# ichigo kurosaki:
# 49    we can t waste time worrying about the what if...
# Name: Quote, dtype: object
# nico robin:
# 50    fools who don t respect the past are likely to...
# Name: Quote, dtype: object
# hiroshi kido:
# 51    that s why i can t make a change  everything i...
# Name: Quote, dtype: object
# kanade jinguuji:
# 52    sometimes it s necessary to do unnecessary thi...
# Name: Quote, dtype: object
# nico yazawa:
# 53    an excellent leader must be passionate because...
# Name: Quote, dtype: object
# princess lenessia:
# 54    protecting someone means giving them a place t...
# Name: Quote, dtype: object
# nobito:
# 55    thinking you re no good and worthless is the w...
# Name: Quote, dtype: object
# izuku midoriya:
# 56    sometimes i do feel like i m a failure  like t...
# Name: Quote, dtype: object
# allen walker:
# 58    when you lose sight of your path  listen for t...
# Name: Quote, dtype: object
# shintaro midorima:
# 60    don t give up  there s no shame in falling dow...
# Name: Quote, dtype: object
# sora:
# 62    life is not a game of luck  if you wanna win  ...
# Name: Quote, dtype: object
# roy mustang:
# 63    the world isn t perfect  but it s there for us...
# 68    the world s not perfect  but it s there for us...
# Name: Quote, dtype: object
# gildarts clive:
# 64    fear is not evil  it tells you what your weakn...
# Name: Quote, dtype: object
# matsumoto rangiku:
# 65    to know sorrow is not terrifying  what is terr...
# Name: Quote, dtype: object
# miss kobayashi:
# 66    knowing you re different is only the beginning...
# Name: Quote, dtype: object
# clare:
# 67    don t be so quick to throw away your life  no ...
# Name: Quote, dtype: object
# hitsugaya toshiro:
# 69    we are all like fireworks  we climb  we shine ...
# Name: Quote, dtype: object
# alibaba saluja:
# 70    if nobody cares to accept you and wants you in...
# 84    if nobody cares to accept you and wants you in...
# Name: Quote, dtype: object
# don quixote doflamingo:
# 72    those who stand at the top determine what s wr...
# Name: Quote, dtype: object
# mavis vermillion:
# 75    mistakes are not shackles that halt one from s...
# Name: Quote, dtype: object
# satsuki kiryuuin:
# 76    fear is freedom  subjugation is liberation  co...
# Name: Quote, dtype: object
# sebastian michaelis:
# 77    hatred and sorrow are power  they are yours to...
# Name: Quote, dtype: object
# might guy:
# 78    it s not always possible to do what we want to...
# Name: Quote, dtype: object
# yato:
# 79    life and death are like light and shadow  they...
# Name: Quote, dtype: object
# grimsley:
# 80    it s more important to master the cards you re...
# Name: Quote, dtype: object
# son goku:
# 81    i am the hope of the universe  i am the answer...
# Name: Quote, dtype: object
# hatsu kominato:
# 82    if you re gonna insist on gambling and then co...
# Name: Quote, dtype: object
# erza scarlet:
# 83    moving on doesn t mean you forget about things...
# Name: Quote, dtype: object
# haruhi fujioka:
# 85    if you keep on hiding your true feelings  who ...
# Name: Quote, dtype: object
# paine:
# 86    religion  ideology  resources  land  spite  lo...
# Name: Quote, dtype: object
# keima katsuragi:
# 87    don t be upset because of what you can t do  d...
# Name: Quote, dtype: object
# erwin smith:
# 88    if you begin to regret  you ll dull your futur...
# Name: Quote, dtype: object
# jet black:
# 89    everything has a beginning and an end  life is...
# Name: Quote, dtype: object
# kyousuke natsume:
# 90    anything can happen  no one ever thinks it wil...
# Name: Quote, dtype: object
# kagome:
# 92    i want you to be happy  i want you to laugh a ...
# Name: Quote, dtype: object
# edward elric :
# 93     a lesson without pain is meaningless  that s ...
# Name: Quote, dtype: object
# roronoa zoro:
# 94    you need to accept the fact that you re not th...
# Name: Quote, dtype: object
# julis alexia van riessfeld:
# 95    i too will obtain everything that i desire  no...
# Name: Quote, dtype: object
# junichirou kagami:
# 96    you can t win a game by doing nothing  and if ...
# 99    just like games  no matter how well you have t...
# Name: Quote, dtype: object
# mion sonozaki:
# 98    life is like a tube of toothpaste  when you ve...
# Name: Quote, dtype: object
# gilgamesh:
# 100    do exactly as you like  that is the true meani...
# Name: Quote, dtype: object
# eren:
# 101    it doesn t matter how strong the opposition is...
# 105    if you win you live if you lose you die if you...
# Name: Quote, dtype: object
# miche zacharius:
# 104    as long as we continue to fight we are not def...
# Name: Quote, dtype: object
# hange zoë:
# 106    you understand don t you one day or another ev...
# Name: Quote, dtype: object
# ymir:
# 107    you re gonna care what other people think and ...
# Name: Quote, dtype: object
# kenny ackerman:
# 108    everyone had to be drunk on somethin to keep p...
# Name: Quote, dtype: object
# mikasa:
# 109    this world is cruel and it s also very beautiful
# Name: Quote, dtype: object
# levi ackerman:
# 110    no one knows what the outcome will be so choos...
# Name: Quote, dtype: object
# shoyo hinata:
# 111    do you need a reason to not want to lose
# Name: Quote, dtype: object
# tobio kageyama:
# 112    being the best decoy ever is as cool as being ...
# 113                              you can fly even higher
# 114    if they adjust to me i have to adjust in turn ...
# 115    the last ones standing are the victors only th...
# Name: Quote, dtype: object
# yuu nishinoya:
# 116    life s a bore if you don t challenge yourself
# Name: Quote, dtype: object
# tanaka saeko:
# 117    there are some flowers you only see when you t...
# Name: Quote, dtype: object
# ittetsu takeda:
# 118    being weak means that there is room to grow
# Name: Quote, dtype: object
# tooru oikawa:
# 119    today might be the chance to grasp the chance ...
# 120        if you re gonna hit it hit it until it breaks
# Name: Quote, dtype: object

# %%
# Yeager is honestly my inspiration for everything. Not even a joke. Call me Yeager. Eren Yeager

eren_quotes = get_lines_by_character('eren', df)
for quote in eren_quotes:
    print(quote)
# Out:
# it doesn t matter how strong the opposition is it doesn t matter how fearsome the world is it doesn t matter how cruel the world is fight
# if you win you live if you lose you die if you don t fight you can t win
